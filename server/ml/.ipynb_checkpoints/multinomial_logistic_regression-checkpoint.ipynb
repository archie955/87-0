# %% [markdown]
# Multinomial Logistic regression

# %%
import pandas as pd

col_names = [
    "name",
    "position",
    "number_of_maps",
    "firepower",
    "entrying",
    "trading",
    "opening",
    "clutching",
    "sniping",
    "utility",
]

data = pd.read_csv("./Training_Data.csv")
data.head()
# Out:
#         name  position  number_of_maps  firepower  entrying  trading  opening  \
# 0    alex666    Closer              83         27        44       43       26
# 1        npl    Opener              83         85        44       60       76
# 2   kensizor    Opener              83         70        94       56       63
# 3  esenthial  Linchpin              83         31        40       79       22
# 4      s1zzi     AWPer              83         57        47       32       77
#
#    clutching  sniping  utility  igl
# 0         58        0       61    1
# 1         47        0       48    0
# 2         37        0       41    0
# 3         61        0       23    0
# 4         63       93       33    0

# %%
for col in [
    "firepower",
    "entrying",
    "trading",
    "opening",
    "clutching",
    "sniping",
    "utility",
]:
    data[col] = data[col] / 100

data.head()
# Out:
#         name  position  number_of_maps  firepower  entrying  trading  opening  \
# 0    alex666    Closer              83       0.27      0.44     0.43     0.26
# 1        npl    Opener              83       0.85      0.44     0.60     0.76
# 2   kensizor    Opener              83       0.70      0.94     0.56     0.63
# 3  esenthial  Linchpin              83       0.31      0.40     0.79     0.22
# 4      s1zzi     AWPer              83       0.57      0.47     0.32     0.77
#
#    clutching  sniping  utility  igl
# 0       0.58     0.00     0.61    1
# 1       0.47     0.00     0.48    0
# 2       0.37     0.00     0.41    0
# 3       0.61     0.00     0.23    0
# 4       0.63     0.93     0.33    0

# %%
feature_cols = [
    "firepower",
    "entrying",
    "trading",
    "opening",
    "clutching",
    "sniping",
    "utility",
]
train_data = data.loc[data["igl"] == 0]

train_data.head()
# Out:
#         name  position  number_of_maps  firepower  entrying  trading  opening  \
# 1        npl    Opener              83       0.85      0.44     0.60     0.76
# 2   kensizor    Opener              83       0.70      0.94     0.56     0.63
# 3  esenthial  Linchpin              83       0.31      0.40     0.79     0.22
# 4      s1zzi     AWPer              83       0.57      0.47     0.32     0.77
# 5   Magnojez    Opener              67       0.88      0.42     0.32     0.85
#
#    clutching  sniping  utility  igl
# 1       0.47     0.00     0.48    0
# 2       0.37     0.00     0.41    0
# 3       0.61     0.00     0.23    0
# 4       0.63     0.93     0.33    0
# 5       0.47     0.03     0.82    0

# %%
X = train_data[feature_cols]
Y = train_data[["position", "number_of_maps"]]

Y.head()
# Out:
#    position  number_of_maps
# 1    Opener              83
# 2    Opener              83
# 3  Linchpin              83
# 4     AWPer              83
# 5    Opener              67

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.25, random_state=16
)

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression(random_state=16)

sample_weight = np.sqrt(Y_train["number_of_maps"])

clf = logreg.fit(X_train, Y_train["position"], sample_weight)

y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import classification_report

target_names = ["AWPer", "Opener", "Closer", "Linchpin"]

print(classification_report(Y_test["position"], y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#        AWPer       1.00      1.00      1.00         7
#       Opener       0.75      0.43      0.55         7
#       Closer       0.50      0.71      0.59         7
#     Linchpin       0.71      0.71      0.71         7
#
#     accuracy                           0.71        28
#    macro avg       0.74      0.71      0.71        28
# weighted avg       0.74      0.71      0.71        28

# %%
print(logreg.predict(np.array([0.7, 0.2, 0.5, 0.2, 0.6, 0.9, 0.4]).reshape(1, -1)))
# Out:
# ['AWPer']
# /home/archie955/cs2/server/.venv/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
print(clf.coef_, clf.intercept_)

# in order: AWPer, Closer, Linchpin, Opener
# features: ["firepower", "entrying", "trading", "opening", "clutching", "sniping", "utility"]
# Out:
# [[-0.42187192 -1.34080623  0.7002286  -0.31827815  0.63352332  5.60015919
#    0.49163951]
#  [ 0.17163596 -1.59469123 -0.5338313  -1.34109246  1.330811   -2.1673989
#   -0.34600496]
#  [-1.01054263  0.17660953  0.4428465  -3.30218437  0.15481059 -2.16884361
#   -1.55257279]
#  [ 1.26077859  2.75888793 -0.60924381  4.96155498 -2.11914491 -1.26391668
#    1.40693825]] [-1.63141799  2.00967444  3.57564945 -3.95390591]

# %%
print(clf.classes_)
# Out:
# ['AWPer' 'Closer' 'Linchpin' 'Opener']

# %%
print(clf.feature_names_in_)
# Out:
# ['firepower' 'entrying' 'trading' 'opening' 'clutching' 'sniping'
#  'utility']
